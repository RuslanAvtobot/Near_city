# %%
import pandas as pd
import numpy as np
import math
import json

# %%
from chardet.universaldetector import UniversalDetector
detector = UniversalDetector()
with open('cities.csv', 'rb') as fh:
    for line in fh:
        detector.feed(line)
        if detector.done:
            break
    detector.close()
print(detector.result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
cities = pd.read_csv('cities.csv', encoding = 'utf-8')
cities.sample(5)
# Out:
#        Индекс Тип региона         Регион Тип района        Район Тип города  \
# 622  606803.0         обл  Нижегородская        р-н     Уренский          г
# 749  347210.0         обл     Ростовская        р-н  Морозовский          г
# 959  636615.0         обл        Томская        NaN          NaN          г
# 178  368000.0        Респ       Дагестан        NaN          NaN          г
# 718  692851.0        край     Приморский        NaN          NaN          г
#
#           Город Тип н/п  Н/п      Код КЛАДР  ... Уровень по ФИАС  \
# 622       Урень     NaN  NaN  5204500100000  ...        4: город
# 749   Морозовск     NaN  NaN  6102500100000  ...        4: город
# 959    Кедровый     NaN  NaN  7000000200000  ...        4: город
# 178    Хасавюрт     NaN  NaN   500000900000  ...        4: город
# 718  Партизанск     NaN  NaN  2500000500000  ...        4: город
#
#     Признак центра района или региона    Код ОКАТО     Код ОКТМО  Код ИФНС  \
# 622                                 1  22254501000  2.265410e+10      5235
# 749                                 1  60234501000  6.063410e+10      6192
# 959                                 0  69407000000  6.970700e+10      7000
# 178                                 0  82435000000  8.273500e+10       544
# 718                                 0   5417000000  5.717000e+06      2509
#
#      Часовой пояс     Широта     Долгота  Федеральный округ Население
# 622         UTC+3  57.461255   45.783394        Приволжский     12311
# 749         UTC+3  48.351172   41.830801              Южный     27644
# 959         UTC+7  57.561846   79.567891          Сибирский      2451
# 178         UTC+3  43.250519   46.585228  Северо-Кавказский    133929
# 718        UTC+10  43.127983  133.126475    Дальневосточный     38648
#
# [5 rows x 21 columns]

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112 entries, 0 to 1111
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Индекс                             1108 non-null   float64
#  1   Тип региона                        1112 non-null   object
#  2   Регион                             1112 non-null   object
#  3   Тип района                         629 non-null    object
#  4   Район                              629 non-null    object
#  5   Тип города                         1108 non-null   object
#  6   Город                              1108 non-null   object
#  7   Тип н/п                            2 non-null      object
#  8   Н/п                                2 non-null      object
#  9   Код КЛАДР                          1112 non-null   int64
#  10  Код ФИАС                           1112 non-null   object
#  11  Уровень по ФИАС                    1112 non-null   object
#  12  Признак центра района или региона  1112 non-null   int64
#  13  Код ОКАТО                          1112 non-null   int64
#  14  Код ОКТМО                          1110 non-null   float64
#  15  Код ИФНС                           1112 non-null   int64
#  16  Часовой пояс                       1112 non-null   object
#  17  Широта                             1112 non-null   float64
#  18  Долгота                            1112 non-null   float64
#  19  Федеральный округ                  1112 non-null   object
#  20  Население                          1112 non-null   object
# dtypes: float64(4), int64(4), object(13)
# memory usage: 182.6+ KB

# %%
cities.columns
# Out:
# Index(['Индекс', 'Тип региона', 'Регион', 'Тип района', 'Район', 'Тип города',
#        'Город', 'Тип н/п', 'Н/п', 'Код КЛАДР', 'Код ФИАС', 'Уровень по ФИАС',
#        'Признак центра района или региона', 'Код ОКАТО', 'Код ОКТМО',
#        'Код ИФНС', 'Часовой пояс', 'Широта', 'Долгота', 'Федеральный округ',
#        'Население'],
#       dtype='object')

# %%
cities.drop(['Индекс', 'Тип региона', 'Тип н/п', 'Н/п', 'Код КЛАДР', 'Код ФИАС', 'Уровень по ФИАС',
       'Признак центра района или региона', 'Код ОКАТО', 'Код ОКТМО',
       'Код ИФНС', 'Федеральный округ'], axis = 1, inplace = True)

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 0 to 1111
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Регион        1108 non-null   object
#  1   Тип района    628 non-null    object
#  2   Район         628 non-null    object
#  3   Тип города    1108 non-null   object
#  4   Город         1108 non-null   object
#  5   Часовой пояс  1108 non-null   object
#  6   Широта        1108 non-null   float64
#  7   Долгота       1108 non-null   float64
#  8   Население     1108 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 86.6+ KB

# %%
cities.dropna(subset = ['Город'], inplace = True)

# %%
cities[cities['Город'] == 'Казань']
# Out:
#         Регион Тип района Район Тип города   Город Часовой пояс     Широта  \
# 924  Татарстан        NaN   NaN          г  Казань        UTC+3  55.794388
#
#        Долгота Население
# 924  49.111531   1216965

# %%
cities['Часовой пояс'] = cities['Часовой пояс'].str.replace('UTC+', '')#удаляю UTC из часового пояса

# %%
cities['Часовой пояс'] = cities['Часовой пояс'].str.replace(' ', '')

# %%
cities['Часовой пояс'] = cities['Часовой пояс'].apply(lambda x: np.int(x))

# %%
cities['Часовой пояс'].unique()
# Out:
# array([ 3,  7,  9,  4,  5,  8, 10,  2, 12, 11,  6], dtype=int64)

# %%
cities[cities['Город'] == 'Белогорск']['Часовой пояс']
# Out:
# 15     9
# 423    3
# Name: Часовой пояс, dtype: int64

# %%
cities['Город+Регион'] = cities['Город'] + ' / ' + cities['Регион']
cities['Город+Регион'].value_counts()
# Out:
# Малоархангельск / Орловская    1
# Гвардейск / Калининградская    1
# Красный Холм / Тверская        1
# Данков / Липецкая              1
# Черепаново / Новосибирская     1
#                               ..
# Верхоянск / Саха /Якутия/      1
# Курлово / Владимирская         1
# Оханск / Пермский              1
# Петухово / Курганская          1
# Апшеронск / Краснодарский      1
# Name: Город+Регион, Length: 1107, dtype: int64

# %%
cities[cities['Город+Регион'] =='ЯлтаКрым']
# Out:
#     Регион Тип района Район Тип города Город  Часовой пояс     Широта  \
# 419   Крым        NaN   NaN          г  Ялта             3  44.416366
# 434   Крым        NaN   NaN          г  Ялта             3  44.495195
#
#        Долгота Население Город+Регион
# 419  34.044550      8497     ЯлтаКрым
# 434  34.166386     78040     ЯлтаКрым

# %%
cities.drop(index=[419], inplace = True)

# %%
cities['Город+Регион'].value_counts()
# Out:
# СарапулУдмуртская            1
# ТюменьТюменская              1
# АрхангельскАрхангельская     1
# МикуньКоми                   1
# ЗарайскМосковская            1
#                             ..
# ПравдинскКалининградская     1
# Катав-ИвановскЧелябинская    1
# КлинцыБрянская               1
# УрюпинскВолгоградская        1
# КраснослободскМордовия       1
# Name: Город+Регион, Length: 1107, dtype: int64

# %%
for i in cities['Город+Регион']:
    #print(i)
    int(cities[cities['Город+Регион'] == i]['Часовой пояс'].values)+2.5

# %%
#Отсекаем часовые пояса +- 2 часа
near_Kazan = cities[cities['Часовой пояс'].between(float(cities[cities['Город'] == 'Самара']['Часовой пояс'].values)-2.5,
                                            float(cities[cities['Город'] == 'Самара']['Часовой пояс'].values)+2.5,
                                            inclusive = True)]

# %%
# Отсекаем города по Долготе
near_Kazan = near_Kazan[near_Kazan['Долгота'].between(float(near_Kazan[near_Kazan['Город'] == 'Самара']['Долгота'].values)-1,
                                            float(near_Kazan[near_Kazan['Город'] == 'Самара']['Долгота'].values)+1,
                                            inclusive = True)]

# %%
math.cos(round(float(near_Kazan[near_Kazan['Город'] == 'Самара']['Широта'].values), 6) * 0.017)
# Out:
# 0.618221918105964

# %%
max_latitude = 40000/360 * math.cos(round(float(near_Kazan[near_Kazan['Город'] == 'Самара']['Широта'].values), 6) * 0.017)
print(max_latitude)
# Out:
# 68.69132423399601

# %%
latitude = round(111.111/(max_latitude/60)/60, 6)
latitude
# Out:
# 1.617541

# %%
near_Kazan = near_Kazan[near_Kazan['Широта'].between(float(near_Kazan[near_Kazan['Город'] == 'Самара']
                                                           ['Широта'].values)-latitude,
                                                     float(near_Kazan[near_Kazan['Город'] == 'Самара']
                                                           ['Широта'].values)+latitude,
                                            inclusive = True)]

# %%
near_Kazan
# Out:
#            Регион Тип района       Район Тип города           Город  \
# 771     Самарская        NaN         NaN          г       Жигулевск
# 772     Самарская        NaN         NaN          г          Кинель
# 774     Самарская        NaN         NaN          г  Новокуйбышевск
# 778     Самарская        NaN         NaN          г          Самара
# 780     Самарская        NaN         NaN          г        Тольятти
# 781     Самарская        NaN         NaN          г        Чапаевск
# 932     Татарстан        р-н  Нурлатский          г          Нурлат
# 1000  Ульяновская        NaN         NaN          г    Димитровград
#
#       Часовой пояс     Широта    Долгота Население             Город+Регион
# 771              4  53.401155  49.494529     57565       ЖигулевскСамарская
# 772              4  53.220999  50.634304     34472          КинельСамарская
# 774              4  53.099530  49.947766    108449  НовокуйбышевскСамарская
# 778              4  53.195166  50.106769   1164900          СамараСамарская
# 780              4  53.520644  49.389461    719484        ТольяттиСамарская
# 781              4  52.928966  49.867422     72689        ЧапаевскСамарская
# 932              3  54.428158  50.805043     32600          НурлатТатарстан
# 1000             4  54.216845  49.626165    122549  ДимитровградУльяновская

# %%
near_sity_s = dict()

near_sity_s['Казань'] = list()

for i in near_Kazan['Город']:
    near_sity_s['Казань'].append(i)

print(near_sity_s)
# Out:
# {'Казань': ['Жигулевск', 'Кинель', 'Новокуйбышевск', 'Самара', 'Тольятти', 'Чапаевск', 'Нурлат', 'Димитровград']}

# %%
sev_city = ['Казань', 'Самара', 'Ульяновск', 'Альметьевск']

# %%
several_city = cities.query('Город in ["Казань","Самара"]')

# %%
def near_city(df, distance):
    near_sity_s = dict() #создаю словарь, что бы добавить города
    
    for i in df['Город+Регион']:
        near_sity_s[i] = list()
    
        #Отсекаем часовые пояса +- 2 часа
        near_Kazan = df[df['Часовой пояс'].between(float(df[df['Город+Регион'] == i]['Часовой пояс'].values)-2.5,
                                                float(df[df['Город+Регион'] == i ]['Часовой пояс'].values)+2.5,
                                                inclusive = True)]
    
        # Отсекаем города по Долготе
        longitude = distance/111.111
        near_Kazan = near_Kazan[near_Kazan['Долгота'].between(float(near_Kazan[near_Kazan['Город+Регион'] == i]
                                                            ['Долгота'].values)-longitude,
                                                float(near_Kazan[near_Kazan['Город+Регион'] == i]
                                                      ['Долгота'].values)+longitude,
                                                inclusive = True)]
    
        latitude = 40000/360 * math.cos(float(near_Kazan[near_Kazan['Город+Регион'] == i]['Широта'].values)*0.017)
        latitude = round(distance/(latitude/60)/60, 6)
    
        # Отсекаем города по Широте
        near_Kazan = near_Kazan[near_Kazan['Широта'].between(float(near_Kazan[near_Kazan['Город+Регион'] == i]
                                                               ['Широта'].values)-latitude,
                                                         float(near_Kazan[near_Kazan['Город+Регион'] == i]
                                                               ['Широта'].values)+latitude,
                                                inclusive = True)]
    
        for j in near_Kazan['Город+Регион']:
            near_sity_s[i].append(j)

    return near_sity_s

# %% [markdown]
# Отсекаем часовые пояса +\- 2 часа
# Считам длину долготы - разница +\- 111 км
# Длина 1 градуса широты 40000\*cos(широты) - 1 градус - длина широты \ 360, в градусе 60 минут -
#    пересчитываем в десятичные доли - 1 градус + 1 мин\60
# Находим по разницы широты +\- 1 градус, долготы расчётная разница, список городов
# Выводим списко городов

# %%
summary = near_city(cities, 50)

# %%
print(summary)
# Out:
# {'Самара': ['Жигулевск', 'Кинель', 'Новокуйбышевск', 'Самара', 'Тольятти', 'Чапаевск', 'Нурлат', 'Димитровград'], 'Казань': ['Уржум', 'Волжск', 'Арск', 'Болгар', 'Буинск', 'Зеленодольск', 'Иннополис', 'Казань', 'Лаишево', 'Тетюши', 'Ульяновск', 'Козловка']}

# %%
jsonData = json.dumps(summary)

# %%
with open("json_near_city.json", "w") as file:
    file.write(jsonData)

# %%
with open('json_near_city.json') as f:
   expl = json.load(f)

# %%
from pprint import pprint  
pprint(expl)
# Out:
# {'Абаза / Хакасия': ['Абаза / Хакасия'],
#  'Абакан / Хакасия': ['Минусинск / Красноярский',
#                       'Абакан / Хакасия',
#                       'Саяногорск / Хакасия',
#                       'Черногорск / Хакасия'],
#  'Абдулино / Оренбургская': ['Абдулино / Оренбургская', 'Бавлы / Татарстан'],
#  'Абинск / Краснодарский': ['Абинск / Краснодарский',
#                             'Геленджик / Краснодарский',
#                             'Крымск / Краснодарский',
#                             'Новороссийск / Краснодарский',
#                             'Славянск-на-Кубани / Краснодарский'],
#  'Агидель / Башкортостан': ['Агидель / Башкортостан',
#                             'Нефтекамск / Башкортостан',
#                             'Камбарка / Удмуртская',
#                             'Сарапул / Удмуртская'],
#  'Агрыз / Татарстан': ['Агрыз / Татарстан', 'Ижевск / Удмуртская'],
#  'Адыгейск / Адыгея': ['Адыгейск / Адыгея',
#                        'Горячий Ключ / Краснодарский',
#                        'Кореновск / Краснодарский',
#                        'Краснодар / Краснодарский',
#                        'Хадыженск / Краснодарский'],
#  'Азнакаево / Татарстан': ['Октябрьский / Башкортостан',
#                            'Азнакаево / Татарстан',
#                            'Бавлы / Татарстан',
#                            'Бугульма / Татарстан'],
#  'Азов / Ростовская': ['Азов / Ростовская',
#                        'Батайск / Ростовская',
#                        'Ростов-на-Дону / Ростовская'],
#  'Ак-Довурак / Тыва': ['Ак-Довурак / Тыва'],
#  'Аксай / Ростовская': ['Аксай / Ростовская',
#                         'Батайск / Ростовская',
#                         'Зерноград / Ростовская',
#                         'Красный Сулин / Ростовская',
#                         'Новочеркасск / Ростовская',
#                         'Новошахтинск / Ростовская',
#                         'Ростов-на-Дону / Ростовская',
#                         'Шахты / Ростовская'],
#  'Алагир / Северная Осетия - Алания': ['Малгобек / Ингушетия',
#                                        'Майский / Кабардино-Балкарская',
#                                        'Нарткала / Кабардино-Балкарская',
#                                        'Терек / Кабардино-Балкарская',
#                                        'Алагир / Северная Осетия - Алания',
#                                        'Ардон / Северная Осетия - Алания',
#                                        'Беслан / Северная Осетия - Алания',
#                                        'Дигора / Северная Осетия - Алания'],
#  'Алапаевск / Свердловская': ['Алапаевск / Свердловская',
#                               'Артемовский / Свердловская',
#                               'Реж / Свердловская'],
#  'Алатырь / Чувашская Республика': ['Ардатов / Мордовия',
#                                     'Алатырь / Чувашская Республика',
#                                     'Шумерля / Чувашская Республика'],
#  'Алдан / Саха /Якутия/': ['Алдан / Саха /Якутия/'],
#  'Алейск / Алтайский': ['Алейск / Алтайский'],
#  'Александров / Владимирская': ['Александров / Владимирская',
#                                 'Карабаново / Владимирская',
#                                 'Киржач / Владимирская',
#                                 'Струнино / Владимирская',
#                                 'Дрезна / Московская',
#                                 'Ликино-Дулево / Московская',
#                                 'Ногинск / Московская',
#                                 'Орехово-Зуево / Московская',
#                                 'Павловский Посад / Московская',
#                                 'Черноголовка / Московская',
#                                 'Электрогорск / Московская',
#                                 'Электросталь / Московская',
#                                 'Переславль-Залесский / Ярославская'],
#  'Александровск / Пермский': ['Александровск / Пермский',
#                               'Гремячинск / Пермский',
#                               'Губаха / Пермский',
#                               'Кизел / Пермский'],
#  'Александровск-Сахалинский / Сахалинская': ['Александровск-Сахалинский / '
#                                              'Сахалинская'],
#  'Алексеевка / Белгородская': ['Алексеевка / Белгородская',
#                                'Бирюч / Белгородская',
#                                'Острогожск / Воронежская'],
#  'Алексин / Тульская': ['Балабаново / Калужская',
#                         'Белоусово / Калужская',
#                         'Жуков / Калужская',
#                         'Кременки / Калужская',
#                         'Обнинск / Калужская',
#                         'Таруса / Калужская',
#                         'Протвино / Московская',
#                         'Серпухов / Московская',
#                         'Чехов / Московская',
#                         'Алексин / Тульская'],
#  'Алзамай / Иркутская': ['Алзамай / Иркутская', 'Нижнеудинск / Иркутская'],
#  'Алушта / Крым': ['Алушта / Крым',
#                    'Белогорск / Крым',
#                    'Симферополь / Крым',
#                    'Ялта / Крым'],
#  'Альметьевск / Татарстан': ['Альметьевск / Татарстан',
#                              'Заинск / Татарстан',
#                              'Лениногорск / Татарстан'],
#  'Амурск / Хабаровский': ['Амурск / Хабаровский',
#                           'Комсомольск-на-Амуре / Хабаровский'],
#  'Анадырь / Чукотский': ['Анадырь / Чукотский'],
#  'Анапа / Краснодарский': ['Анапа / Краснодарский', 'Темрюк / Краснодарский'],
#  'Ангарск / Иркутская': ['Ангарск / Иркутская',
#                          'Иркутск / Иркутская',
#                          'Усолье-Сибирское / Иркутская',
#                          'Шелехов / Иркутская'],
#  'Андреаполь / Тверская': ['Андреаполь / Тверская',
#                            'Западная Двина / Тверская'],
#  'Анжеро-Судженск / Кемеровская': ['Анжеро-Судженск / Кемеровская',
#                                    'Березовский / Кемеровская',
#                                    'Кемерово / Кемеровская',
#                                    'Тайга / Кемеровская'],
#  'Анива / Сахалинская': ['Анива / Сахалинская',
#                          'Долинск / Сахалинская',
#                          'Корсаков / Сахалинская',
#                          'Южно-Сахалинск / Сахалинская'],
#  'Апатиты / Мурманская': ['Апатиты / Мурманская',
#                           'Кировск / Мурманская',
#                           'Оленегорск / Мурманская'],
#  'Апрелевка / Московская': ['Балабаново / Калужская',
#                             'Белоусово / Калужская',
#                             'Жуков / Калужская',
#                             'Кременки / Калужская',
#                             'Апрелевка / Московская',
#                             'Голицыно / Московская',
#                             'Дедовск / Московская',
#                             'Долгопрудный / Московская',
#                             'Звенигород / Московская',
#                             'Истра / Московская',
#                             'Красногорск / Московская',
#                             'Краснознаменск / Московская',
#                             'Кубинка / Московская',
#                             'Лобня / Московская',
#                             'Наро-Фоминск / Московская',
#                             'Одинцово / Московская',
#                             'Протвино / Московская',
#                             'Серпухов / Московская',
#                             'Солнечногорск / Московская',
#                             'Химки / Московская',
#                             'Чехов / Московская',
#                             'Яхрома / Московская'],
#  'Апшеронск / Краснодарский': ['Майкоп / Адыгея',
#                                'Апшеронск / Краснодарский',
#                                'Белореченск / Краснодарский',
#                                'Хадыженск / Краснодарский'],
#  'Арамиль / Свердловская': ['Арамиль / Свердловская',
#                             'Березовский / Свердловская',
#                             'Верхняя Пышма / Свердловская',
#                             'Екатеринбург / Свердловская',
#                             'Среднеуральск / Свердловская',
#                             'Сысерть / Свердловская',
#                             'Снежинск / Челябинская'],
#  'Аргун / Чеченская': ['Аргун / Чеченская',
#                        'Грозный / Чеченская',
#                        'Гудермес / Чеченская',
#                        'Шали / Чеченская'],
#  'Ардатов / Мордовия': ['Ардатов / Мордовия',
#                         'Алатырь / Чувашская Республика',
#                         'Шумерля / Чувашская Республика'],
#  'Ардон / Северная Осетия - Алания': ['Малгобек / Ингушетия',
#                                       'Майский / Кабардино-Балкарская',
#                                       'Нарткала / Кабардино-Балкарская',
#                                       'Прохладный / Кабардино-Балкарская',
#                                       'Терек / Кабардино-Балкарская',
#                                       'Алагир / Северная Осетия - Алания',
#                                       'Ардон / Северная Осетия - Алания',
#                                       'Беслан / Северная Осетия - Алания',
#                                       'Владикавказ / Северная Осетия - Алания',
#                                       'Дигора / Северная Осетия - Алания',
#                                       'Моздок / Северная Осетия - Алания'],
#  'Арзамас / Нижегородская': ['Арзамас / Нижегородская',
#                              'Богородск / Нижегородская',
#                              'Кстово / Нижегородская',
#                              'Первомайск / Нижегородская'],
#  'Аркадак / Саратовская': ['Аркадак / Саратовская',
#                            'Балашов / Саратовская',
#                            'Ртищево / Саратовская'],
#  'Армавир / Краснодарский': ['Армавир / Краснодарский',
#                              'Гулькевичи / Краснодарский',
#                              'Лабинск / Краснодарский',
#                              'Новокубанск / Краснодарский',
#                              'Новоалександровск / Ставропольский'],
#  'Армянск / Крым': ['Армянск / Крым', 'Красноперекопск / Крым'],
#  'Арсеньев / Приморский': ['Арсеньев / Приморский'],
#  'Арск / Татарстан': ['Арск / Татарстан', 'Лаишево / Татарстан'],
#  'Артем / Приморский': ['Артем / Приморский',
#                         'Большой Камень / Приморский',
#                         'Владивосток / Приморский',
#                         'Уссурийск / Приморский',
#                         'Фокино / Приморский'],
#  'Артемовск / Красноярский': ['Артемовск / Красноярский'],
#  'Артемовский / Свердловская': ['Алапаевск / Свердловская',
#                                 'Артемовский / Свердловская',
#                                 'Асбест / Свердловская',
#                                 'Богданович / Свердловская',
#                                 'Сухой Лог / Свердловская'],
#  'Архангельск / Архангельская': ['Архангельск / Архангельская',
#                                  'Новодвинск / Архангельская'],
#  'Асбест / Свердловская': ['Артемовский / Свердловская',
#                            'Асбест / Свердловская',
#                            'Заречный / Свердловская',
#                            'Реж / Свердловская'],
#  'Асино / Томская': ['Асино / Томская'],
#  'Астрахань / Астраханская': ['Астрахань / Астраханская',
#                               'Камызяк / Астраханская',
#                               'Нариманов / Астраханская'],
#  'Аткарск / Саратовская': ['Аткарск / Саратовская', 'Петровск / Саратовская'],
#  'Ахтубинск / Астраханская': ['Ахтубинск / Астраханская'],
#  'Ачинск / Красноярский': ['Ачинск / Красноярский', 'Назарово / Красноярский'],
#  'Аша / Челябинская': ['Аша / Челябинская',
#                        'Миньяр / Челябинская',
#                        'Сим / Челябинская'],
#  'Бабаево / Вологодская': ['Бабаево / Вологодская', 'Пестово / Новгородская'],
#  'Бабушкин / Бурятия': ['Бабушкин / Бурятия'],
#  'Бавлы / Татарстан': ['Октябрьский / Башкортостан',
#                        'Туймазы / Башкортостан',
#                        'Абдулино / Оренбургская',
#                        'Азнакаево / Татарстан',
#                        'Бавлы / Татарстан'],
#  'Багратионовск / Калининградская': ['Багратионовск / Калининградская',
#                                      'Гвардейск / Калининградская',
#                                      'Гурьевск / Калининградская',
#                                      'Зеленоградск / Калининградская',
#                                      'Калининград / Калининградская',
#                                      'Пионерский / Калининградская',
#                                      'Правдинск / Калининградская'],
#  'Байкальск / Иркутская': ['Байкальск / Иркутская',
#                            'Слюдянка / Иркутская',
#                            'Шелехов / Иркутская'],
#  'Баймак / Башкортостан': ['Баймак / Башкортостан', 'Сибай / Башкортостан'],
#  'Бакал / Челябинская': ['Бакал / Челябинская',
#                          'Сатка / Челябинская',
#                          'Трехгорный / Челябинская',
#                          'Юрюзань / Челябинская'],
#  'Баксан / Кабардино-Балкарская': ['Баксан / Кабардино-Балкарская',
#                                    'Нальчик / Кабардино-Балкарская',
#                                    'Нарткала / Кабардино-Балкарская',
#                                    'Чегем / Кабардино-Балкарская',
#                                    'Георгиевск / Ставропольский',
#                                    'Минеральные Воды / Ставропольский',
#                                    'Новопавловск / Ставропольский'],
#  'Балабаново / Калужская': ['Балабаново / Калужская',
#                             'Белоусово / Калужская',
#                             'Боровск / Калужская',
#                             'Ермолино / Калужская',
#                             'Жуков / Калужская',
#                             'Калуга / Калужская',
#                             'Малоярославец / Калужская',
#                             'Обнинск / Калужская',
#                             'Апрелевка / Московская',
#                             'Голицыно / Московская',
#                             'Звенигород / Московская',
#                             'Истра / Московская',
#                             'Краснознаменск / Московская',
#                             'Кубинка / Московская',
#                             'Наро-Фоминск / Московская',
#                             'Алексин / Тульская'],
#  'Балаково / Саратовская': ['Балаково / Саратовская',
#                             'Вольск / Саратовская',
#                             'Хвалынск / Саратовская'],
#  'Балахна / Нижегородская': ['Пучеж / Ивановская',
#                              'Балахна / Нижегородская',
#                              'Богородск / Нижегородская',
#                              'Володарск / Нижегородская',
#                              'Ворсма / Нижегородская',
#                              'Городец / Нижегородская',
#                              'Дзержинск / Нижегородская',
#                              'Заволжье / Нижегородская',
#                              'Нижний Новгород / Нижегородская',
#                              'Чкаловск / Нижегородская'],
#  'Балашиха / Московская': ['Балашиха / Московская',
#                            'Бронницы / Московская',
#                            'Видное / Московская',
#                            'Дзержинский / Московская',
#                            'Дмитров / Московская',
#                            'Долгопрудный / Московская',
#                            'Домодедово / Московская',
#                            'Жуковский / Московская',
#                            'Ивантеевка / Московская',
#                            'Королев / Московская',
#                            'Котельники / Московская',
#                            'Краснозаводск / Московская',
#                            'Лосино-Петровский / Московская',
#                            'Лыткарино / Московская',
#                            'Люберцы / Московская',
#                            'Мытищи / Московская',
#                            'Пересвет / Московская',
#                            'Подольск / Московская',
#                            'Пушкино / Московская',
#                            'Раменское / Московская',
#                            'Реутов / Московская',
#                            'Сергиев Посад / Московская',
#                            'Старая Купавна / Московская',
#                            'Фрязино / Московская',
#                            'Хотьково / Московская',
#                            'Черноголовка / Московская',
#                            'Щелково / Московская',
#                            'Электроугли / Московская'],
#  'Балашов / Саратовская': ['Аркадак / Саратовская', 'Балашов / Саратовская'],
#  'Балей / Забайкальский': ['Балей / Забайкальский', 'Нерчинск / Забайкальский'],
#  'Балтийск / Калининградская': ['Балтийск / Калининградская',
#                                 'Ладушкин / Калининградская',
#                                 'Мамоново / Калининградская',
#                                 'Пионерский / Калининградская',
#                                 'Приморск / Калининградская',
#                                 'Светлогорск / Калининградская',
#                                 'Светлый / Калининградская'],
#  'Барабинск / Новосибирская': ['Барабинск / Новосибирская',
#                                'Куйбышев / Новосибирская'],
#  'Барнаул / Алтайский': ['Барнаул / Алтайский', 'Новоалтайск / Алтайский'],
#  'Барыш / Ульяновская': ['Барыш / Ульяновская'],
#  'Батайск / Ростовская': ['Азов / Ростовская',
#                           'Аксай / Ростовская',
#                           'Батайск / Ростовская',
#                           'Новочеркасск / Ростовская',
#                           'Новошахтинск / Ростовская',
#                           'Ростов-на-Дону / Ростовская'],
#  'Бахчисарай / Крым': ['Бахчисарай / Крым',
#                        'Саки / Крым',
#                        'Симферополь / Крым',
#                        'Ялта / Крым',
#                        'Инкерман / Севастополь'],
#  'Бежецк / Тверская': ['Бежецк / Тверская', 'Красный Холм / Тверская'],
#  'Белая Калитва / Ростовская': ['Белая Калитва / Ростовская',
#                                 'Константиновск / Ростовская'],
#  'Белая Холуница / Кировская': ['Белая Холуница / Кировская',
#                                 'Зуевка / Кировская'],
#  'Белгород / Белгородская': ['Белгород / Белгородская',
#                              'Строитель / Белгородская',
#                              'Шебекино / Белгородская',
#                              'Обоянь / Курская'],
#  'Белебей / Башкортостан': ['Белебей / Башкортостан', 'Туймазы / Башкортостан'],
#  'Белев / Тульская': ['Калуга / Калужская',
#                       'Козельск / Калужская',
#                       'Сосенский / Калужская',
#                       'Болхов / Орловская',
#                       'Мценск / Орловская',
#                       'Белев / Тульская',
#                       'Суворов / Тульская',
#                       'Чекалин / Тульская'],
#  'Белинский / Пензенская': ['Белинский / Пензенская',
#                             'Нижний Ломов / Пензенская',
#                             'Ртищево / Саратовская'],
#  'Белово / Кемеровская': ['Белово / Кемеровская',
#                           'Гурьевск / Кемеровская',
#                           'Киселевск / Кемеровская',
#                           'Ленинск-Кузнецкий / Кемеровская',
#                           'Полысаево / Кемеровская',
#                           'Прокопьевск / Кемеровская'],
#  'Белогорск / Амурская': ['Белогорск / Амурская', 'Свободный / Амурская'],
#  'Белогорск / Крым': ['Алушта / Крым',
#                       'Белогорск / Крым',
#                       'Судак / Крым',
#                       'Ялта / Крым'],
#  'Белозерск / Вологодская': ['Белозерск / Вологодская'],
#  'Белокуриха / Алтайский': ['Белокуриха / Алтайский', 'Бийск / Алтайский'],
#  'Беломорск / Карелия': ['Беломорск / Карелия', 'Кемь / Карелия'],
#  'Белорецк / Башкортостан': ['Белорецк / Башкортостан',
#                              'Межгорье / Башкортостан'],
#  'Белореченск / Краснодарский': ['Майкоп / Адыгея',
#                                  'Апшеронск / Краснодарский',
#                                  'Белореченск / Краснодарский',
#                                  'Усть-Лабинск / Краснодарский',
#                                  'Хадыженск / Краснодарский'],
#  'Белоусово / Калужская': ['Балабаново / Калужская',
#                            'Белоусово / Калужская',
#                            'Боровск / Калужская',
#                            'Ермолино / Калужская',
#                            'Жуков / Калужская',
#                            'Калуга / Калужская',
#                            'Кременки / Калужская',
#                            'Малоярославец / Калужская',
#                            'Обнинск / Калужская',
#                            'Апрелевка / Московская',
#                            'Голицыно / Московская',
#                            'Звенигород / Московская',
#                            'Краснознаменск / Московская',
#                            'Кубинка / Московская',
#                            'Наро-Фоминск / Московская',
#                            'Алексин / Тульская'],
#  'Белоярский / Ханты-Мансийский Автономный округ - Югра': ['Белоярский / '
#                                                            'Ханты-Мансийский '
#                                                            'Автономный округ - '
#                                                            'Югра'],
#  'Белый / Тверская': ['Сафоново / Смоленская',
#                       'Белый / Тверская',
#                       'Нелидово / Тверская'],
#  'Бердск / Новосибирская': ['Бердск / Новосибирская',
#                             'Искитим / Новосибирская',
#                             'Новосибирск / Новосибирская',
#                             'Обь / Новосибирская',
#                             'Черепаново / Новосибирская'],
#  'Березники / Пермский': ['Березники / Пермский',
#                           'Соликамск / Пермский',
#                           'Усолье / Пермский'],
#  'Березовский / Кемеровская': ['Анжеро-Судженск / Кемеровская',
#                                'Березовский / Кемеровская',
#                                'Кемерово / Кемеровская'],
#  'Березовский / Свердловская': ['Арамиль / Свердловская',
#                                 'Березовский / Свердловская',
#                                 'Верхняя Пышма / Свердловская',
#                                 'Екатеринбург / Свердловская',
#                                 'Среднеуральск / Свердловская',
#                                 'Сысерть / Свердловская'],
#  'Беслан / Северная Осетия - Алания': ['Карабулак / Ингушетия',
#                                        'Магас / Ингушетия',
#                                        'Малгобек / Ингушетия',
#                                        'Назрань / Ингушетия',
#                                        'Терек / Кабардино-Балкарская',
#                                        'Алагир / Северная Осетия - Алания',
#                                        'Ардон / Северная Осетия - Алания',
#                                        'Беслан / Северная Осетия - Алания',
#                                        'Владикавказ / Северная Осетия - Алания',
#                                        'Дигора / Северная Осетия - Алания',
#                                        'Моздок / Северная Осетия - Алания'],
#  'Бийск / Алтайский': ['Белокуриха / Алтайский', 'Бийск / Алтайский'],
#  'Бикин / Хабаровский': ['Бикин / Хабаровский'],
#  'Билибино / Чукотский': ['Билибино / Чукотский'],
#  'Биробиджан / Еврейская': ['Биробиджан / Еврейская'],
#  'Бирск / Башкортостан': ['Бирск / Башкортостан',
#                           'Благовещенск / Башкортостан',
#                           'Уфа / Башкортостан'],
#  'Бирюсинск / Иркутская': ['Бирюсинск / Иркутская', 'Тайшет / Иркутская'],
#  'Бирюч / Белгородская': ['Алексеевка / Белгородская',
#                           'Бирюч / Белгородская',
#                           'Валуйки / Белгородская'],
#  'Благовещенск / Амурская': ['Благовещенск / Амурская'],
#  'Благовещенск / Башкортостан': ['Бирск / Башкортостан',
#                                  'Благовещенск / Башкортостан',
#                                  'Уфа / Башкортостан'],
#  'Благодарный / Ставропольский': ['Благодарный / Ставропольский'],
#  'Бобров / Воронежская': ['Бобров / Воронежская', 'Павловск / Воронежская'],
#  'Богданович / Свердловская': ['Артемовский / Свердловская',
#                                'Богданович / Свердловская',
#                                'Каменск-Уральский / Свердловская',
#                                'Сухой Лог / Свердловская'],
#  'Богородицк / Тульская': ['Богородицк / Тульская',
#                            'Болохово / Тульская',
#                            'Венев / Тульская',
#                            'Донской / Тульская',
#                            'Ефремов / Тульская',
#                            'Кимовск / Тульская',
#                            'Киреевск / Тульская',
#                            'Липки / Тульская',
#                            'Новомосковск / Тульская',
#                            'Узловая / Тульская',
#                            'Ясногорск / Тульская'],
#  'Богородск / Нижегородская': ['Арзамас / Нижегородская',
#                                'Балахна / Нижегородская',
#                                'Богородск / Нижегородская',
#                                'Володарск / Нижегородская',
#                                'Ворсма / Нижегородская',
#                                'Городец / Нижегородская',
#                                'Дзержинск / Нижегородская',
#                                'Заволжье / Нижегородская',
#                                'Павлово / Нижегородская',
#                                'Чкаловск / Нижегородская'],
#  'Боготол / Красноярский': ['Боготол / Красноярский',
#                             'Шарыпово / Красноярский'],
#  'Богучар / Воронежская': ['Богучар / Воронежская', 'Павловск / Воронежская'],
#  'Бодайбо / Иркутская': ['Бодайбо / Иркутская'],
#  'Бокситогорск / Ленинградская': ['Бокситогорск / Ленинградская',
#                                   'Пикалево / Ленинградская',
#                                   'Тихвин / Ленинградская'],
#  'Болгар / Татарстан': ['Болгар / Татарстан', 'Тетюши / Татарстан'],
#  'Бологое / Тверская': ['Боровичи / Новгородская', 'Бологое / Тверская'],
#  'Болотное / Новосибирская': ['Болотное / Новосибирская',
#                               'Тогучин / Новосибирская'],
#  'Болохово / Тульская': ['Богородицк / Тульская',
#                          'Болохово / Тульская',
#                          'Венев / Тульская',
#                          'Киреевск / Тульская',
#                          'Липки / Тульская',
#                          'Советск / Тульская',
#                          'Тула / Тульская',
#                          'Узловая / Тульская',
#                          'Щекино / Тульская',
#                          'Ясногорск / Тульская'],
#  'Болхов / Орловская': ['Козельск / Калужская',
#                         'Сосенский / Калужская',
#                         'Болхов / Орловская',
#                         'Орёл / Орловская',
#                         'Белев / Тульская',
#                         'Чекалин / Тульская'],
#  'Большой Камень / Приморский': ['Артем / Приморский',
#                                  'Большой Камень / Приморский',
#                                  'Фокино / Приморский'],
#  'Бор / Нижегородская': ['Бор / Нижегородская',
#                          'Кстово / Нижегородская',
#                          'Нижний Новгород / Нижегородская',
#                          'Семенов / Нижегородская'],
#  'Борзя / Забайкальский': ['Борзя / Забайкальский'],
#  'Борисоглебск / Воронежская': ['Урюпинск / Волгоградская',
#                                 'Борисоглебск / Воронежская',
#                                 'Поворино / Воронежская',
#                                 'Уварово / Тамбовская'],
#  'Боровичи / Новгородская': ['Боровичи / Новгородская', 'Бологое / Тверская'],
#  'Боровск / Калужская': ['Балабаново / Калужская',
#                          'Белоусово / Калужская',
#                          'Боровск / Калужская',
#                          'Ермолино / Калужская',
#                          'Жуков / Калужская',
#                          'Калуга / Калужская',
#                          'Малоярославец / Калужская',
#                          'Обнинск / Калужская',
#                          'Верея / Московская',
#                          'Звенигород / Московская',
#                          'Истра / Московская',
#                          'Кубинка / Московская',
#                          'Наро-Фоминск / Московская',
#                          'Руза / Московская'],
#  'Бородино / Красноярский': ['Бородино / Красноярский',
#                              'Заозерный / Красноярский',
#                              'Зеленогорск / Красноярский'],
#  'Братск / Иркутская': ['Братск / Иркутская'],
#  'Бронницы / Московская': ['Балашиха / Московская',
#                            'Бронницы / Московская',
#                            'Воскресенск / Московская',
#                            'Дзержинский / Московская',
#                            'Жуковский / Московская',
#                            'Ивантеевка / Московская',
#                            'Кашира / Московская',
#                            'Королев / Московская',
#                            'Котельники / Московская',
#                            'Лосино-Петровский / Московская',
#                            'Лыткарино / Московская',
#                            'Люберцы / Московская',
#                            'Ногинск / Московская',
#                            'Озеры / Московская',
#                            'Павловский Посад / Московская',
#                            'Пушкино / Московская',
#                            'Раменское / Московская',
#                            'Реутов / Московская',
#                            'Старая Купавна / Московская',
#                            'Ступино / Московская',
#                            'Фрязино / Московская',
#                            'Черноголовка / Московская',
#                            'Щелково / Московская',
#                            'Электросталь / Московская',
#                            'Электроугли / Московская'],
#  'Брянск / Брянская': ['Брянск / Брянская',
#                        'Дятьково / Брянская',
#                        'Сельцо / Брянская',
#                        'Фокино / Брянская',
#                        'Жиздра / Калужская',
#                        'Людиново / Калужская'],
#  'Бугульма / Татарстан': ['Азнакаево / Татарстан',
#                           'Бугульма / Татарстан',
#                           'Лениногорск / Татарстан'],
#  'Бугуруслан / Оренбургская': ['Бугуруслан / Оренбургская',
#                                'Похвистнево / Самарская'],
#  'Буденновск / Ставропольский': ['Буденновск / Ставропольский',
#                                  'Зеленокумск / Ставропольский'],
#  'Бузулук / Оренбургская': ['Бузулук / Оренбургская'],
#  'Буинск / Татарстан': ['Буинск / Татарстан', 'Ульяновск / Ульяновская'],
#  'Буй / Костромская': ['Буй / Костромская'],
#  'Буйнакск / Дагестан': ['Буйнакск / Дагестан',
#                          'Кизилюрт / Дагестан',
#                          'Махачкала / Дагестан'],
#  'Бутурлиновка / Воронежская': ['Бутурлиновка / Воронежская',
#                                 'Калач / Воронежская'],
#  'Валдай / Новгородская': ['Валдай / Новгородская', 'Окуловка / Новгородская'],
#  'Валуйки / Белгородская': ['Бирюч / Белгородская',
#                             'Валуйки / Белгородская',
#                             'Новый Оскол / Белгородская'],
#  'Велиж / Смоленская': ['Велиж / Смоленская',
#                         'Демидов / Смоленская',
#                         'Рудня / Смоленская'],
#  'Великие Луки / Псковская': ['Великие Луки / Псковская',
#                               'Новосокольники / Псковская'],
#  'Великий Новгород / Новгородская': ['Великий Новгород / Новгородская',
#                                      'Старая Русса / Новгородская',
#                                      'Чудово / Новгородская'],
#  'Великий Устюг / Вологодская': ['Котлас / Архангельская',
#                                  'Великий Устюг / Вологодская',
#                                  'Красавино / Вологодская'],
#  'Вельск / Архангельская': ['Вельск / Архангельская'],
#  'Венев / Тульская': ['Кашира / Московская',
#                       'Озеры / Московская',
#                       'Ступино / Московская',
#                       'Богородицк / Тульская',
#                       'Болохово / Тульская',
#                       'Венев / Тульская',
#                       'Донской / Тульская',
#                       'Кимовск / Тульская',
#                       'Киреевск / Тульская',
#                       'Новомосковск / Тульская',
#                       'Узловая / Тульская'],
#  'Верещагино / Пермский': ['Верещагино / Пермский', 'Очер / Пермский'],
#  'Верея / Московская': ['Боровск / Калужская',
#                         'Ермолино / Калужская',
#                         'Кондрово / Калужская',
#                         'Малоярославец / Калужская',
#                         'Медынь / Калужская',
#                         'Верея / Московская',
#                         'Волоколамск / Московская',
#                         'Можайск / Московская',
#                         'Руза / Московская'],
#  'Верхнеуральск / Челябинская': ['Учалы / Башкортостан',
#                                  'Верхнеуральск / Челябинская',
#                                  'Магнитогорск / Челябинская'],
#  'Верхний Тагил / Свердловская': ['Верхний Тагил / Свердловская',
#                                   'Дегтярск / Свердловская',
#                                   'Кировград / Свердловская',
#                                   'Невьянск / Свердловская',
#                                   'Нижний Тагил / Свердловская',
#                                   'Новоуральск / Свердловская',
#                                   'Первоуральск / Свердловская',
#                                   'Ревда / Свердловская'],
#  'Верхний Уфалей / Челябинская': ['Дегтярск / Свердловская',
#                                   'Полевской / Свердловская',
#                                   'Ревда / Свердловская',
#                                   'Верхний Уфалей / Челябинская',
#                                   'Карабаш / Челябинская',
#                                   'Кыштым / Челябинская'],
#  'Верхняя Пышма / Свердловская': ['Арамиль / Свердловская',
#                                   'Березовский / Свердловская',
#                                   'Верхняя Пышма / Свердловская',
#                                   'Екатеринбург / Свердловская',
#                                   'Невьянск / Свердловская',
#                                   'Полевской / Свердловская',
#                                   'Среднеуральск / Свердловская',
#                                   'Сысерть / Свердловская'],
#  'Верхняя Салда / Свердловская': ['Верхняя Салда / Свердловская',
#                                   'Верхотурье / Свердловская',
#                                   'Невьянск / Свердловская',
#                                   'Нижняя Салда / Свердловская'],
#  'Верхняя Тура / Свердловская': ['Верхняя Тура / Свердловская',
#                                  'Качканар / Свердловская',
#                                  'Красноуральск / Свердловская',
#                                  'Кушва / Свердловская',
#                                  'Лесной / Свердловская',
#                                  'Нижний Тагил / Свердловская',
#                                  'Нижняя Тура / Свердловская'],
#  'Верхотурье / Свердловская': ['Верхняя Салда / Свердловская',
#                                'Верхотурье / Свердловская',
#                                'Нижняя Салда / Свердловская',
#                                'Новая Ляля / Свердловская',
#                                'Серов / Свердловская'],
#  'Верхоянск / Саха /Якутия/': ['Верхоянск / Саха /Якутия/'],
#  'Весьегонск / Тверская': ['Весьегонск / Тверская', 'Красный Холм / Тверская'],
#  'Ветлуга / Нижегородская': ['Шарья / Костромская',
#                              'Ветлуга / Нижегородская',
#                              'Урень / Нижегородская'],
#  'Видное / Московская': ['Балашиха / Московская',
#                          'Видное / Московская',
#                          'Дзержинский / Московская',
#                          'Долгопрудный / Московская',
#                          'Домодедово / Московская',
#                          'Жуковский / Московская',
#                          'Ивантеевка / Московская',
#                          'Королев / Московская',
#                          'Котельники / Московская',
#                          'Красногорск / Московская',
#                          'Лобня / Московская',
#                          'Лыткарино / Московская',
#                          'Люберцы / Московская',
#                          'Мытищи / Московская',
#                          'Одинцово / Московская',
#                          'Подольск / Московская',
#                          'Пушкино / Московская',
#                          'Пущино / Московская',
#                          'Реутов / Московская',
#                          'Сергиев Посад / Московская',
#                          'Серпухов / Московская',
#                          'Старая Купавна / Московская',
#                          'Ступино / Московская',
#                          'Фрязино / Московская',
#                          'Химки / Московская',
#                          'Хотьково / Московская',
#                          'Чехов / Московская',
#                          'Щелково / Московская',
#                          'Яхрома / Московская'],
#  'Вилюйск / Саха /Якутия/': ['Вилюйск / Саха /Якутия/'],
#  'Вилючинск / Камчатский': ['Вилючинск / Камчатский',
#                             'Елизово / Камчатский',
#                             'Петропавловск-Камчатский / Камчатский'],
#  'Вихоревка / Иркутская': ['Вихоревка / Иркутская'],
#  'Вичуга / Ивановская': ['Вичуга / Ивановская',
#                          'Заволжск / Ивановская',
#                          'Кинешма / Ивановская',
#                          'Наволоки / Ивановская',
#                          'Плес / Ивановская',
#                          'Родники / Ивановская',
#                          'Южа / Ивановская'],
#  'Владивосток / Приморский': ['Артем / Приморский', 'Владивосток / Приморский'],
#  'Владикавказ / Северная Осетия - Алания': ['Карабулак / Ингушетия',
#                                             'Магас / Ингушетия',
#                                             'Малгобек / Ингушетия',
#                                             'Назрань / Ингушетия',
#                                             'Ардон / Северная Осетия - Алания',
#                                             'Беслан / Северная Осетия - Алания',
#                                             'Владикавказ / Северная Осетия - '
#                                             'Алания'],
#  'Владимир / Владимирская': ['Владимир / Владимирская',
#                              'Гусь-Хрустальный / Владимирская',
#                              'Курлово / Владимирская',
#                              'Радужный / Владимирская',
#                              'Собинка / Владимирская',
#                              'Судогда / Владимирская',
#                              'Суздаль / Владимирская',
#                              'Гаврилов Посад / Ивановская',
#                              'Тейково / Ивановская'],
#  'Волгоград / Волгоградская': ['Волгоград / Волгоградская',
#                                'Волжский / Волгоградская',
#                                'Дубовка / Волгоградская',
#                                'Краснослободск / Волгоградская'],
#  'Волгодонск / Ростовская': ['Волгодонск / Ростовская',
#                              'Цимлянск / Ростовская'],
#  'Волгореченск / Костромская': ['Иваново / Ивановская',
#                                 'Кохма / Ивановская',
#                                 'Плес / Ивановская',
#                                 'Приволжск / Ивановская',
#                                 'Фурманов / Ивановская',
#                                 'Шуя / Ивановская',
#                                 'Волгореченск / Костромская',
#                                 'Кострома / Костромская'],
#  'Волжск / Марий Эл': ['Волжск / Марий Эл',
#                        'Звенигово / Марий Эл',
#                        'Зеленодольск / Татарстан',
#                        'Иннополис / Татарстан',
#                        'Козловка / Чувашская Республика'],
#  'Волжский / Волгоградская': ['Волгоград / Волгоградская',
#                               'Волжский / Волгоградская',
#                               'Дубовка / Волгоградская',
#                               'Краснослободск / Волгоградская'],
#  'Вологда / Вологодская': ['Вологда / Вологодская',
#                            'Грязовец / Вологодская',
#                            'Сокол / Вологодская',
#                            'Харовск / Вологодская'],
#  'Володарск / Нижегородская': ['Пучеж / Ивановская',
#                                'Балахна / Нижегородская',
#                                'Богородск / Нижегородская',
#                                'Володарск / Нижегородская',
#                                'Ворсма / Нижегородская',
#                                'Горбатов / Нижегородская',
#                                'Городец / Нижегородская',
#                                'Дзержинск / Нижегородская',
#                                'Заволжье / Нижегородская',
#                                'Павлово / Нижегородская',
#                                'Чкаловск / Нижегородская'],
#  'Волоколамск / Московская': ['Верея / Московская',
#                               'Волоколамск / Московская',
#                               'Можайск / Московская',
#                               'Руза / Московская'],
#  'Волосово / Ленинградская': ['Волосово / Ленинградская',
#                               'Луга / Ленинградская',
#                               'Сосновый Бор / Ленинградская'],
#  'Волхов / Ленинградская': ['Волхов / Ленинградская',
#                             'Кириши / Ленинградская',
#                             'Новая Ладога / Ленинградская',
#                             'Сясьстрой / Ленинградская'],
#  'Волчанск / Свердловская': ['Волчанск / Свердловская',
#                              'Ивдель / Свердловская',
#                              'Карпинск / Свердловская',
#                              'Краснотурьинск / Свердловская',
#                              'Североуральск / Свердловская'],
#  'Вольск / Саратовская': ['Балаково / Саратовская',
#                           'Вольск / Саратовская',
#                           'Шиханы / Саратовская'],
#  'Воркута / Коми': ['Воркута / Коми'],
#  'Воронеж / Воронежская': ['Воронеж / Воронежская',
#                            'Лиски / Воронежская',
#                            'Нововоронеж / Воронежская',
#                            'Семилуки / Воронежская'],
#  'Ворсма / Нижегородская': ['Балахна / Нижегородская',
#                             'Богородск / Нижегородская',
#                             'Володарск / Нижегородская',
#                             'Ворсма / Нижегородская',
#                             'Горбатов / Нижегородская',
#                             'Городец / Нижегородская',
#                             'Дзержинск / Нижегородская',
#                             'Заволжье / Нижегородская',
#                             'Павлово / Нижегородская',
#                             'Чкаловск / Нижегородская'],
#  'Воскресенск / Московская': ['Бронницы / Московская',
#                               'Воскресенск / Московская',
#                               'Дрезна / Московская',
#                               'Егорьевск / Московская',
#                               'Зарайск / Московская',
#                               'Коломна / Московская',
#                               'Куровское / Московская',
#                               'Ликино-Дулево / Московская',
#                               'Луховицы / Московская',
#                               'Ногинск / Московская',
#                               'Озеры / Московская',
#                               'Орехово-Зуево / Московская',
#                               'Павловский Посад / Московская',
#                               'Раменское / Московская',
#                               'Черноголовка / Московская',
#                               'Электрогорск / Московская',
#                               'Электросталь / Московская'],
#  'Воткинск / Удмуртская': ['Чайковский / Пермский',
#                            'Воткинск / Удмуртская',
#                            'Камбарка / Удмуртская',
#                            'Сарапул / Удмуртская'],
#  'Всеволожск / Ленинградская': ['Всеволожск / Ленинградская',
#                                 'Кировск / Ленинградская',
#                                 'Коммунар / Ленинградская',
#                                 'Никольское / Ленинградская',
#                                 'Отрадное / Ленинградская',
#                                 'Сертолово / Ленинградская',
#                                 'Тосно / Ленинградская',
#                                 'Шлиссельбург / Ленинградская'],
#  'Вуктыл / Коми': ['Вуктыл / Коми'],
#  'Выборг / Ленинградская': ['Выборг / Ленинградская',
#                             'Высоцк / Ленинградская',
#                             'Каменногорск / Ленинградская',
#                             'Приморск / Ленинградская',
#                             'Светогорск / Ленинградская',
#                             'Сосновый Бор / Ленинградская'],
#  'Выкса / Нижегородская': ['Муром / Владимирская',
#                            'Выкса / Нижегородская',
#                            'Кулебаки / Нижегородская',
#                            'Навашино / Нижегородская'],
#  'Высоковск / Московская': ['Высоковск / Московская',
#                             'Звенигород / Московская',
#                             'Истра / Московская',
#                             'Клин / Московская',
#                             'Кубинка / Московская',
#                             'Руза / Московская',
#                             'Конаково / Тверская'],
#  'Высоцк / Ленинградская': ['Выборг / Ленинградская',
#                             'Высоцк / Ленинградская',
#                             'Приморск / Ленинградская',
#                             'Светогорск / Ленинградская'],
#  'Вытегра / Вологодская': ['Вытегра / Вологодская', 'Пудож / Карелия'],
#  'Вышний Волочек / Тверская': ['Вышний Волочек / Тверская',
#                                'Кувшиново / Тверская',
#                                'Торжок / Тверская'],
#  'Вяземский / Хабаровский': ['Вяземский / Хабаровский'],
#  'Вязники / Владимирская': ['Вязники / Владимирская',
#                             'Гороховец / Владимирская',
#                             'Муром / Владимирская',
#                             'Южа / Ивановская',
#                             'Навашино / Нижегородская'],
#  'Вязьма / Смоленская': ['Вязьма / Смоленская', 'Сычевка / Смоленская'],
#  'Вятские Поляны / Кировская': ['Вятские Поляны / Кировская',
#                                 'Малмыж / Кировская',
#                                 'Сосновка / Кировская',
#                                 'Мамадыш / Татарстан'],
#  'Гаврилов Посад / Ивановская': ['Владимир / Владимирская',
#                                  'Лакинск / Владимирская',
#                                  'Радужный / Владимирская',
#                                  'Собинка / Владимирская',
#                                  'Суздаль / Владимирская',
#                                  'Гаврилов Посад / Ивановская',
#                                  'Комсомольск / Ивановская',
#                                  'Тейково / Ивановская',
#                                  'Гаврилов-Ям / Ярославская'],
#  'Гаврилов-Ям / Ярославская': ['Гаврилов Посад / Ивановская',
#                                'Гаврилов-Ям / Ярославская',
#                                'Ростов / Ярославская',
#                                'Тутаев / Ярославская',
#                                'Ярославль / Ярославская'],
#  'Гагарин / Смоленская': ['Гагарин / Смоленская', 'Зубцов / Тверская'],
#  'Гаджиево / Мурманская': ['Гаджиево / Мурманская',
#                            'Кола / Мурманская',
#                            'Мурманск / Мурманская',
# ...
#                               'Городец / Нижегородская',
#                               'Дзержинск / Нижегородская',
#                               'Заволжье / Нижегородская',
#                               'Павлово / Нижегородская',
#                               'Чкаловск / Нижегородская'],
#  'Чудово / Новгородская': ['Кириши / Ленинградская',
#                            'Любань / Ленинградская',
#                            'Великий Новгород / Новгородская',
#                            'Чудово / Новгородская'],
#  'Чулым / Новосибирская': ['Чулым / Новосибирская'],
#  'Чусовой / Пермский': ['Гремячинск / Пермский',
#                         'Губаха / Пермский',
#                         'Кизел / Пермский',
#                         'Лысьва / Пермский',
#                         'Чусовой / Пермский'],
#  'Чухлома / Костромская': ['Галич / Костромская',
#                            'Солигалич / Костромская',
#                            'Чухлома / Костромская'],
#  'Шагонар / Тыва': ['Шагонар / Тыва'],
#  'Шадринск / Курганская': ['Шадринск / Курганская'],
#  'Шали / Чеченская': ['Аргун / Чеченская',
#                       'Грозный / Чеченская',
#                       'Гудермес / Чеченская',
#                       'Шали / Чеченская'],
#  'Шарыпово / Красноярский': ['Боготол / Красноярский',
#                              'Шарыпово / Красноярский'],
#  'Шарья / Костромская': ['Шарья / Костромская', 'Ветлуга / Нижегородская'],
#  'Шатура / Московская': ['Кольчугино / Владимирская',
#                          'Костерево / Владимирская',
#                          'Лакинск / Владимирская',
#                          'Петушки / Владимирская',
#                          'Покров / Владимирская',
#                          'Рошаль / Московская',
#                          'Шатура / Московская'],
#  'Шахты / Ростовская': ['Аксай / Ростовская',
#                         'Гуково / Ростовская',
#                         'Донецк / Ростовская',
#                         'Зверево / Ростовская',
#                         'Каменск-Шахтинский / Ростовская',
#                         'Красный Сулин / Ростовская',
#                         'Новочеркасск / Ростовская',
#                         'Новошахтинск / Ростовская',
#                         'Шахты / Ростовская'],
#  'Шахунья / Нижегородская': ['Шахунья / Нижегородская'],
#  'Шацк / Рязанская': ['Сасово / Рязанская',
#                       'Шацк / Рязанская',
#                       'Моршанск / Тамбовская'],
#  'Шебекино / Белгородская': ['Белгород / Белгородская',
#                              'Короча / Белгородская',
#                              'Строитель / Белгородская',
#                              'Шебекино / Белгородская'],
#  'Шелехов / Иркутская': ['Ангарск / Иркутская',
#                          'Байкальск / Иркутская',
#                          'Иркутск / Иркутская',
#                          'Слюдянка / Иркутская',
#                          'Шелехов / Иркутская'],
#  'Шенкурск / Архангельская': ['Шенкурск / Архангельская'],
#  'Шилка / Забайкальский': ['Шилка / Забайкальский'],
#  'Шимановск / Амурская': ['Свободный / Амурская',
#                           'Циолковский / Амурская',
#                           'Шимановск / Амурская'],
#  'Шиханы / Саратовская': ['Вольск / Саратовская', 'Шиханы / Саратовская'],
#  'Шлиссельбург / Ленинградская': ['Всеволожск / Ленинградская',
#                                   'Кировск / Ленинградская',
#                                   'Любань / Ленинградская',
#                                   'Никольское / Ленинградская',
#                                   'Отрадное / Ленинградская',
#                                   'Тосно / Ленинградская',
#                                   'Шлиссельбург / Ленинградская'],
#  'Шумерля / Чувашская Республика': ['Ардатов / Мордовия',
#                                     'Алатырь / Чувашская Республика',
#                                     'Шумерля / Чувашская Республика',
#                                     'Ядрин / Чувашская Республика'],
#  'Шумиха / Курганская': ['Шумиха / Курганская'],
#  'Шуя / Ивановская': ['Камешково / Владимирская',
#                       'Ковров / Владимирская',
#                       'Иваново / Ивановская',
#                       'Кохма / Ивановская',
#                       'Плес / Ивановская',
#                       'Приволжск / Ивановская',
#                       'Родники / Ивановская',
#                       'Фурманов / Ивановская',
#                       'Шуя / Ивановская',
#                       'Волгореченск / Костромская'],
#  'Щекино / Тульская': ['Таруса / Калужская',
#                        'Болохово / Тульская',
#                        'Киреевск / Тульская',
#                        'Липки / Тульская',
#                        'Плавск / Тульская',
#                        'Советск / Тульская',
#                        'Тула / Тульская',
#                        'Щекино / Тульская',
#                        'Ясногорск / Тульская'],
#  'Щелкино / Крым': ['Феодосия / Крым', 'Щелкино / Крым'],
#  'Щелково / Московская': ['Балашиха / Московская',
#                           'Бронницы / Московская',
#                           'Видное / Московская',
#                           'Дзержинский / Московская',
#                           'Домодедово / Московская',
#                           'Жуковский / Московская',
#                           'Ивантеевка / Московская',
#                           'Королев / Московская',
#                           'Котельники / Московская',
#                           'Краснозаводск / Московская',
#                           'Лосино-Петровский / Московская',
#                           'Лыткарино / Московская',
#                           'Люберцы / Московская',
#                           'Мытищи / Московская',
#                           'Пересвет / Московская',
#                           'Подольск / Московская',
#                           'Пушкино / Московская',
#                           'Раменское / Московская',
#                           'Реутов / Московская',
#                           'Сергиев Посад / Московская',
#                           'Старая Купавна / Московская',
#                           'Фрязино / Московская',
#                           'Хотьково / Московская',
#                           'Черноголовка / Московская',
#                           'Щелково / Московская',
#                           'Электроугли / Московская'],
#  'Щигры / Курская': ['Щигры / Курская', 'Малоархангельск / Орловская'],
#  'Щучье / Курганская': ['Щучье / Курганская'],
#  'Электрогорск / Московская': ['Александров / Владимирская',
#                                'Карабаново / Владимирская',
#                                'Киржач / Владимирская',
#                                'Покров / Владимирская',
#                                'Струнино / Владимирская',
#                                'Воскресенск / Московская',
#                                'Дрезна / Московская',
#                                'Егорьевск / Московская',
#                                'Куровское / Московская',
#                                'Ликино-Дулево / Московская',
#                                'Ногинск / Московская',
#                                'Орехово-Зуево / Московская',
#                                'Павловский Посад / Московская',
#                                'Черноголовка / Московская',
#                                'Электрогорск / Московская',
#                                'Электросталь / Московская'],
#  'Электросталь / Московская': ['Александров / Владимирская',
#                                'Карабаново / Владимирская',
#                                'Киржач / Владимирская',
#                                'Струнино / Владимирская',
#                                'Бронницы / Московская',
#                                'Воскресенск / Московская',
#                                'Дрезна / Московская',
#                                'Жуковский / Московская',
#                                'Коломна / Московская',
#                                'Краснозаводск / Московская',
#                                'Лосино-Петровский / Московская',
#                                'Ногинск / Московская',
#                                'Павловский Посад / Московская',
#                                'Пересвет / Московская',
#                                'Раменское / Московская',
#                                'Сергиев Посад / Московская',
#                                'Старая Купавна / Московская',
#                                'Фрязино / Московская',
#                                'Черноголовка / Московская',
#                                'Электрогорск / Московская',
#                                'Электросталь / Московская',
#                                'Электроугли / Московская'],
#  'Электроугли / Московская': ['Струнино / Владимирская',
#                               'Балашиха / Московская',
#                               'Бронницы / Московская',
#                               'Дзержинский / Московская',
#                               'Жуковский / Московская',
#                               'Ивантеевка / Московская',
#                               'Королев / Московская',
#                               'Котельники / Московская',
#                               'Краснозаводск / Московская',
#                               'Лосино-Петровский / Московская',
#                               'Лыткарино / Московская',
#                               'Люберцы / Московская',
#                               'Ногинск / Московская',
#                               'Павловский Посад / Московская',
#                               'Пересвет / Московская',
#                               'Пушкино / Московская',
#                               'Раменское / Московская',
#                               'Реутов / Московская',
#                               'Сергиев Посад / Московская',
#                               'Старая Купавна / Московская',
#                               'Фрязино / Московская',
#                               'Хотьково / Московская',
#                               'Черноголовка / Московская',
#                               'Щелково / Московская',
#                               'Электросталь / Московская',
#                               'Электроугли / Московская'],
#  'Элиста / Калмыкия': ['Элиста / Калмыкия'],
#  'Энгельс / Саратовская': ['Красноармейск / Московская',
#                            'Красноармейск / Саратовская',
#                            'Саратов / Саратовская',
#                            'Энгельс / Саратовская'],
#  'Эртиль / Воронежская': ['Эртиль / Воронежская'],
#  'Югорск / Ханты-Мансийский Автономный округ - Югра': ['Советский / '
#                                                        'Ханты-Мансийский '
#                                                        'Автономный округ - '
#                                                        'Югра',
#                                                        'Югорск / '
#                                                        'Ханты-Мансийский '
#                                                        'Автономный округ - '
#                                                        'Югра'],
#  'Южа / Ивановская': ['Вязники / Владимирская',
#                       'Вичуга / Ивановская',
#                       'Родники / Ивановская',
#                       'Южа / Ивановская'],
#  'Южно-Сахалинск / Сахалинская': ['Анива / Сахалинская',
#                                   'Долинск / Сахалинская',
#                                   'Корсаков / Сахалинская',
#                                   'Южно-Сахалинск / Сахалинская'],
#  'Южно-Сухокумск / Дагестан': ['Южно-Сухокумск / Дагестан'],
#  'Южноуральск / Челябинская': ['Еманжелинск / Челябинская',
#                                'Копейск / Челябинская',
#                                'Коркино / Челябинская',
#                                'Пласт / Челябинская',
#                                'Троицк / Челябинская',
#                                'Челябинск / Челябинская',
#                                'Южноуральск / Челябинская'],
#  'Юрга / Кемеровская': ['Юрга / Кемеровская', 'Томск / Томская'],
#  'Юрьев-Польский / Владимирская': ['Кольчугино / Владимирская',
#                                    'Костерево / Владимирская',
#                                    'Лакинск / Владимирская',
#                                    'Петушки / Владимирская',
#                                    'Собинка / Владимирская',
#                                    'Юрьев-Польский / Владимирская',
#                                    'Ростов / Ярославская'],
#  'Юрьевец / Ивановская': ['Пучеж / Ивановская',
#                           'Юрьевец / Ивановская',
#                           'Городец / Нижегородская',
#                           'Заволжье / Нижегородская',
#                           'Чкаловск / Нижегородская'],
#  'Юрюзань / Челябинская': ['Бакал / Челябинская',
#                            'Катав-Ивановск / Челябинская',
#                            'Трехгорный / Челябинская',
#                            'Усть-Катав / Челябинская',
#                            'Юрюзань / Челябинская'],
#  'Юхнов / Калужская': ['Мещовск / Калужская',
#                        'Мосальск / Калужская',
#                        'Сухиничи / Калужская',
#                        'Юхнов / Калужская'],
#  'Ядрин / Чувашская Республика': ['Козьмодемьянск / Марий Эл',
#                                   'Шумерля / Чувашская Республика',
#                                   'Ядрин / Чувашская Республика'],
#  'Якутск / Саха /Якутия/': ['Якутск / Саха /Якутия/'],
#  'Ялта / Крым': ['Алушта / Крым',
#                  'Бахчисарай / Крым',
#                  'Белогорск / Крым',
#                  'Симферополь / Крым',
#                  'Ялта / Крым'],
#  'Ялуторовск / Тюменская': ['Заводоуковск / Тюменская',
#                             'Ялуторовск / Тюменская'],
#  'Янаул / Башкортостан': ['Дюртюли / Башкортостан', 'Янаул / Башкортостан'],
#  'Яранск / Кировская': ['Яранск / Кировская', 'Йошкар-Ола / Марий Эл'],
#  'Яровое / Алтайский': ['Славгород / Алтайский', 'Яровое / Алтайский'],
#  'Ярославль / Ярославская': ['Гаврилов-Ям / Ярославская',
#                              'Данилов / Ярославская',
#                              'Тутаев / Ярославская',
#                              'Ярославль / Ярославская'],
#  'Ярцево / Смоленская': ['Духовщина / Смоленская',
#                          'Починок / Смоленская',
#                          'Ярцево / Смоленская'],
#  'Ясногорск / Тульская': ['Пущино / Московская',
#                           'Серпухов / Московская',
#                           'Ступино / Московская',
#                           'Чехов / Московская',
#                           'Богородицк / Тульская',
#                           'Болохово / Тульская',
#                           'Киреевск / Тульская',
#                           'Липки / Тульская',
#                           'Советск / Тульская',
#                           'Тула / Тульская',
#                           'Щекино / Тульская',
#                           'Ясногорск / Тульская'],
#  'Ясный / Оренбургская': ['Ясный / Оренбургская'],
#  'Яхрома / Московская': ['Апрелевка / Московская',
#                          'Видное / Московская',
#                          'Дедовск / Московская',
#                          'Дзержинский / Московская',
#                          'Дмитров / Московская',
#                          'Долгопрудный / Московская',
#                          'Дубна / Московская',
#                          'Ивантеевка / Московская',
#                          'Королев / Московская',
#                          'Котельники / Московская',
#                          'Красногорск / Московская',
#                          'Краснознаменск / Московская',
#                          'Лобня / Московская',
#                          'Лыткарино / Московская',
#                          'Мытищи / Московская',
#                          'Одинцово / Московская',
#                          'Пушкино / Московская',
#                          'Реутов / Московская',
#                          'Солнечногорск / Московская',
#                          'Талдом / Московская',
#                          'Химки / Московская',
#                          'Яхрома / Московская',
#                          'Кимры / Тверская']}
